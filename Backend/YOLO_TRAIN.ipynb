# %%
from google.colab import drive

drive.mount('/content/gdrive')

# %%
ROOT_DIR = '/content/gdrive/My Drive/PROGRAMMING_FOR_AI/'

# !pip install ultralytics

import os

from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')


results = model.train(data=os.path.join(ROOT_DIR, "train.yaml"), epochs=20)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 56.3MB/s]
# Ultralytics YOLOv8.1.8 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (AMD EPYC 7B12)
# ...

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/PROGRAMMING_FOR_AI/'

# %%
model = YOLO('/content/gdrive/My Drive/PROGRAMMING_FOR_AI/runs/detect/train3/weights/best.pt')

# %%
results = model.predict('/content/gdrive/My Drive/PROGRAMMING_FOR_AI/Predict/', conf = 0.25)
